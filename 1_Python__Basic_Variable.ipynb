# %% [markdown]
# Variables in python

# %% [markdown]
# *  A variables is a name that prefer to value store in memory
# * You can assign using the"="operator.python is dynamicaly typed
#
# > Variable are containers for storing data values.
#
#  Rules for naming variables
# 1. must start with a letter or underscore(_)
# 2. Cannot start with number
# 3. can contain letter,digit,and underscore
# 4. case-sensitive(name#name)
# 5. should not use python keywords ( if,for,class,etc,)

# %% [markdown]
# #Variables Assignment in python

# %%
x=10   # Assigns the integer 10 to variable name x
name="sam" # assigns string "sam"
name
print("name")
print("my name is ", name, "and evryone call me", name)
# Out:
# name
# my name is  sam and evryone call me sam

# %%
# show all varriable types
print(type(x),type(name))
# Out:
# <class 'int'> <class 'str'>
